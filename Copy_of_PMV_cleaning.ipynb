# %% [markdown]
# <a href="https://colab.research.google.com/github/josephthomas08/Amazon_Vine_Analysis/blob/main/Copy_of_PMV_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Step 1: Load the data
covid_19_PMV = pd.read_csv(
    'https://covid.ourworldindata.org/data/owid-covid-data.csv')
covid_19_PMV.head()
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.511
# 1      AFG      Asia  ...           64.83                   0.511
# 2      AFG      Asia  ...           64.83                   0.511
# 3      AFG      Asia  ...           64.83                   0.511
# 4      AFG      Asia  ...           64.83                   0.511
#
# [5 rows x 59 columns]

# %%
covid_19_PMV.shape
# Out:
# (94441, 59)

# %%
pd.options.display.max_columns= 100

# %%
covid_19_PMV.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    0.026                  0.026
# 1                    0.026                  0.000
# 2                    0.026                  0.000
# 3                    0.026                  0.000
# 4                    0.026                  0.000
#
#    new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#    new_deaths_per_million  new_deaths_smoothed_per_million  reproduction_rate  \
# 0                     NaN                              NaN                NaN
# 1                     NaN                              NaN                NaN
# 2                     NaN                              NaN                NaN
# 3                     NaN                              NaN                NaN
# 4                     NaN                              NaN                NaN
#
#    icu_patients  icu_patients_per_million  hosp_patients  \
# 0           NaN                       NaN            NaN
# 1           NaN                       NaN            NaN
# 2           NaN                       NaN            NaN
# 3           NaN                       NaN            NaN
# 4           NaN                       NaN            NaN
#
#    hosp_patients_per_million  weekly_icu_admissions  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
#    weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
#
#    weekly_hosp_admissions_per_million  new_tests  total_tests  \
# 0                                 NaN        NaN          NaN
# 1                                 NaN        NaN          NaN
# 2                                 NaN        NaN          NaN
# 3                                 NaN        NaN          NaN
# 4                                 NaN        NaN          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  positive_rate  tests_per_case tests_units  \
# 0                              NaN            NaN             NaN         NaN
# 1                              NaN            NaN             NaN         NaN
# 2                              NaN            NaN             NaN         NaN
# 3                              NaN            NaN             NaN         NaN
# 4                              NaN            NaN             NaN         NaN
#
#    total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0                 NaN                NaN                      NaN
# 1                 NaN                NaN                      NaN
# 2                 NaN                NaN                      NaN
# 3                 NaN                NaN                      NaN
# 4                 NaN                NaN                      NaN
#
#    new_vaccinations  new_vaccinations_smoothed  \
# 0               NaN                        NaN
# 1               NaN                        NaN
# 2               NaN                        NaN
# 3               NaN                        NaN
# 4               NaN                        NaN
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  new_vaccinations_smoothed_per_million  \
# 0                                  NaN                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
#
#    stringency_index  population  population_density  median_age  \
# 0              8.33  38928341.0              54.422        18.6
# 1              8.33  38928341.0              54.422        18.6
# 2              8.33  38928341.0              54.422        18.6
# 3              8.33  38928341.0              54.422        18.6
# 4              8.33  38928341.0              54.422        18.6
#
#    aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# 0          2.581          1.337        1803.987              NaN
# 1          2.581          1.337        1803.987              NaN
# 2          2.581          1.337        1803.987              NaN
# 3          2.581          1.337        1803.987              NaN
# 4          2.581          1.337        1803.987              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                597.029                 9.59             NaN           NaN
# 1                597.029                 9.59             NaN           NaN
# 2                597.029                 9.59             NaN           NaN
# 3                597.029                 9.59             NaN           NaN
# 4                597.029                 9.59             NaN           NaN
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                  37.746                         0.5            64.83
# 1                  37.746                         0.5            64.83
# 2                  37.746                         0.5            64.83
# 3                  37.746                         0.5            64.83
# 4                  37.746                         0.5            64.83
#
#    human_development_index
# 0                    0.511
# 1                    0.511
# 2                    0.511
# 3                    0.511
# 4                    0.511

# %% [markdown]
# # Info Method

# %%
covid_19_PMV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94441 entries, 0 to 94440
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               94441 non-null  object
#  1   continent                              89979 non-null  object
#  2   location                               94441 non-null  object
#  3   date                                   94441 non-null  object
#  4   total_cases                            91358 non-null  float64
#  5   new_cases                              91355 non-null  float64
#  6   new_cases_smoothed                     90345 non-null  float64
#  7   total_deaths                           81395 non-null  float64
#  8   new_deaths                             81551 non-null  float64
#  9   new_deaths_smoothed                    90345 non-null  float64
#  10  total_cases_per_million                90870 non-null  float64
#  11  new_cases_per_million                  90867 non-null  float64
#  12  new_cases_smoothed_per_million         89862 non-null  float64
#  13  total_deaths_per_million               80920 non-null  float64
#  14  new_deaths_per_million                 81076 non-null  float64
#  15  new_deaths_smoothed_per_million        89862 non-null  float64
#  16  reproduction_rate                      76127 non-null  float64
#  17  icu_patients                           9514 non-null   float64
#  18  icu_patients_per_million               9514 non-null   float64
#  19  hosp_patients                          11810 non-null  float64
#  20  hosp_patients_per_million              11810 non-null  float64
#  21  weekly_icu_admissions                  861 non-null    float64
#  22  weekly_icu_admissions_per_million      861 non-null    float64
#  23  weekly_hosp_admissions                 1496 non-null   float64
#  24  weekly_hosp_admissions_per_million     1496 non-null   float64
#  25  new_tests                              42642 non-null  float64
#  26  total_tests                            42335 non-null  float64
#  27  total_tests_per_thousand               42335 non-null  float64
#  28  new_tests_per_thousand                 42642 non-null  float64
#  29  new_tests_smoothed                     49436 non-null  float64
#  30  new_tests_smoothed_per_thousand        49436 non-null  float64
#  31  positive_rate                          46602 non-null  float64
#  32  tests_per_case                         46003 non-null  float64
#  33  tests_units                            51035 non-null  object
#  34  total_vaccinations                     13879 non-null  float64
#  35  people_vaccinated                      13087 non-null  float64
#  36  people_fully_vaccinated                10326 non-null  float64
#  37  new_vaccinations                       11611 non-null  float64
#  38  new_vaccinations_smoothed              23938 non-null  float64
#  39  total_vaccinations_per_hundred         13879 non-null  float64
#  40  people_vaccinated_per_hundred          13087 non-null  float64
#  41  people_fully_vaccinated_per_hundred    10326 non-null  float64
#  42  new_vaccinations_smoothed_per_million  23938 non-null  float64
#  43  stringency_index                       79883 non-null  float64
#  44  population                             93819 non-null  float64
#  45  population_density                     87804 non-null  float64
#  46  median_age                             84634 non-null  float64
#  47  aged_65_older                          83680 non-null  float64
#  48  aged_70_older                          84165 non-null  float64
#  49  gdp_per_capita                         84918 non-null  float64
#  50  extreme_poverty                        57399 non-null  float64
#  51  cardiovasc_death_rate                  85024 non-null  float64
#  52  diabetes_prevalence                    87079 non-null  float64
#  53  female_smokers                         66553 non-null  float64
#  54  male_smokers                           65578 non-null  float64
#  55  handwashing_facilities                 42713 non-null  float64
#  56  hospital_beds_per_thousand             77509 non-null  float64
#  57  life_expectancy                        89680 non-null  float64
#  58  human_development_index                85190 non-null  float64
# dtypes: float64(54), object(5)
# memory usage: 42.5+ MB

# %% [markdown]
# # Count method

# %%
covid_19_PMV.count()
# Out:
# iso_code                                 94441
# continent                                89979
# location                                 94441
# date                                     94441
# total_cases                              91358
# new_cases                                91355
# new_cases_smoothed                       90345
# total_deaths                             81395
# new_deaths                               81551
# new_deaths_smoothed                      90345
# total_cases_per_million                  90870
# new_cases_per_million                    90867
# new_cases_smoothed_per_million           89862
# total_deaths_per_million                 80920
# new_deaths_per_million                   81076
# new_deaths_smoothed_per_million          89862
# reproduction_rate                        76127
# icu_patients                              9514
# icu_patients_per_million                  9514
# hosp_patients                            11810
# hosp_patients_per_million                11810
# weekly_icu_admissions                      861
# weekly_icu_admissions_per_million          861
# weekly_hosp_admissions                    1496
# weekly_hosp_admissions_per_million        1496
# new_tests                                42642
# total_tests                              42335
# total_tests_per_thousand                 42335
# new_tests_per_thousand                   42642
# new_tests_smoothed                       49436
# new_tests_smoothed_per_thousand          49436
# positive_rate                            46602
# tests_per_case                           46003
# tests_units                              51035
# total_vaccinations                       13879
# people_vaccinated                        13087
# people_fully_vaccinated                  10326
# new_vaccinations                         11611
# new_vaccinations_smoothed                23938
# total_vaccinations_per_hundred           13879
# people_vaccinated_per_hundred            13087
# people_fully_vaccinated_per_hundred      10326
# new_vaccinations_smoothed_per_million    23938
# stringency_index                         79883
# population                               93819
# population_density                       87804
# median_age                               84634
# aged_65_older                            83680
# aged_70_older                            84165
# gdp_per_capita                           84918
# extreme_poverty                          57399
# cardiovasc_death_rate                    85024
# diabetes_prevalence                      87079
# female_smokers                           66553
# male_smokers                             65578
# handwashing_facilities                   42713
# hospital_beds_per_thousand               77509
# life_expectancy                          89680
# human_development_index                  85190
# dtype: int64

# %%
covid_19_PMV_missing= covid_19_PMV.isna()
covid_19_PMV_missing.head()
# Out:
#    iso_code  continent  location   date  total_cases  new_cases  \
# 0     False      False     False  False        False      False
# 1     False      False     False  False        False      False
# 2     False      False     False  False        False      False
# 3     False      False     False  False        False      False
# 4     False      False     False  False        False      False
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                True          True        True                 True
# 1                True          True        True                 True
# 2                True          True        True                 True
# 3                True          True        True                 True
# 4                True          True        True                 True
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    False                  False
# 1                    False                  False
# 2                    False                  False
# 3                    False                  False
# 4                    False                  False
#
#    new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                            True                      True
# 1                            True                      True
# 2                            True                      True
# 3                            True                      True
# 4                            True                      True
#
#    new_deaths_per_million  new_deaths_smoothed_per_million  reproduction_rate  \
# 0                    True                             True               True
# 1                    True                             True               True
# 2                    True                             True               True
# 3                    True                             True               True
# 4                    True                             True               True
#
#    icu_patients  icu_patients_per_million  hosp_patients  \
# 0          True                      True           True
# 1          True                      True           True
# 2          True                      True           True
# 3          True                      True           True
# 4          True                      True           True
#
#    hosp_patients_per_million  weekly_icu_admissions  \
# 0                       True                   True
# 1                       True                   True
# 2                       True                   True
# 3                       True                   True
# 4                       True                   True
#
#    weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                               True                    True
# 1                               True                    True
# 2                               True                    True
# 3                               True                    True
# 4                               True                    True
#
#    weekly_hosp_admissions_per_million  new_tests  total_tests  \
# 0                                True       True         True
# 1                                True       True         True
# 2                                True       True         True
# 3                                True       True         True
# 4                                True       True         True
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                      True                    True                True
# 1                      True                    True                True
# 2                      True                    True                True
# 3                      True                    True                True
# 4                      True                    True                True
#
#    new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# 0                             True           True            True
# 1                             True           True            True
# 2                             True           True            True
# 3                             True           True            True
# 4                             True           True            True
#
#    tests_units  total_vaccinations  people_vaccinated  \
# 0         True                True               True
# 1         True                True               True
# 2         True                True               True
# 3         True                True               True
# 4         True                True               True
#
#    people_fully_vaccinated  new_vaccinations  new_vaccinations_smoothed  \
# 0                     True              True                       True
# 1                     True              True                       True
# 2                     True              True                       True
# 3                     True              True                       True
# 4                     True              True                       True
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            True                           True
# 1                            True                           True
# 2                            True                           True
# 3                            True                           True
# 4                            True                           True
#
#    people_fully_vaccinated_per_hundred  new_vaccinations_smoothed_per_million  \
# 0                                 True                                   True
# 1                                 True                                   True
# 2                                 True                                   True
# 3                                 True                                   True
# 4                                 True                                   True
#
#    stringency_index  population  population_density  median_age  \
# 0             False       False               False       False
# 1             False       False               False       False
# 2             False       False               False       False
# 3             False       False               False       False
# 4             False       False               False       False
#
#    aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# 0          False          False           False             True
# 1          False          False           False             True
# 2          False          False           False             True
# 3          False          False           False             True
# 4          False          False           False             True
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                  False                False            True          True
# 1                  False                False            True          True
# 2                  False                False            True          True
# 3                  False                False            True          True
# 4                  False                False            True          True
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                   False                       False            False
# 1                   False                       False            False
# 2                   False                       False            False
# 3                   False                       False            False
# 4                   False                       False            False
#
#    human_development_index
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
covid_19_PMV_missing.dtypes
# Out:
# iso_code                                 bool
# continent                                bool
# location                                 bool
# date                                     bool
# total_cases                              bool
# new_cases                                bool
# new_cases_smoothed                       bool
# total_deaths                             bool
# new_deaths                               bool
# new_deaths_smoothed                      bool
# total_cases_per_million                  bool
# new_cases_per_million                    bool
# new_cases_smoothed_per_million           bool
# total_deaths_per_million                 bool
# new_deaths_per_million                   bool
# new_deaths_smoothed_per_million          bool
# reproduction_rate                        bool
# icu_patients                             bool
# icu_patients_per_million                 bool
# hosp_patients                            bool
# hosp_patients_per_million                bool
# weekly_icu_admissions                    bool
# weekly_icu_admissions_per_million        bool
# weekly_hosp_admissions                   bool
# weekly_hosp_admissions_per_million       bool
# new_tests                                bool
# total_tests                              bool
# total_tests_per_thousand                 bool
# new_tests_per_thousand                   bool
# new_tests_smoothed                       bool
# new_tests_smoothed_per_thousand          bool
# positive_rate                            bool
# tests_per_case                           bool
# tests_units                              bool
# total_vaccinations                       bool
# people_vaccinated                        bool
# people_fully_vaccinated                  bool
# new_vaccinations                         bool
# new_vaccinations_smoothed                bool
# total_vaccinations_per_hundred           bool
# people_vaccinated_per_hundred            bool
# people_fully_vaccinated_per_hundred      bool
# new_vaccinations_smoothed_per_million    bool
# stringency_index                         bool
# population                               bool
# population_density                       bool
# median_age                               bool
# aged_65_older                            bool
# aged_70_older                            bool
# gdp_per_capita                           bool
# extreme_poverty                          bool
# cardiovasc_death_rate                    bool
# diabetes_prevalence                      bool
# female_smokers                           bool
# male_smokers                             bool
# handwashing_facilities                   bool
# hospital_beds_per_thousand               bool
# life_expectancy                          bool
# human_development_index                  bool
# dtype: object

# %% [markdown]
# # Sum method

# %%
covid_19_PMV_num_missing= covid_19_PMV_missing.sum()
covid_19_PMV_num_missing
# Out:
# iso_code                                     0
# continent                                 4462
# location                                     0
# date                                         0
# total_cases                               3083
# new_cases                                 3086
# new_cases_smoothed                        4096
# total_deaths                             13046
# new_deaths                               12890
# new_deaths_smoothed                       4096
# total_cases_per_million                   3571
# new_cases_per_million                     3574
# new_cases_smoothed_per_million            4579
# total_deaths_per_million                 13521
# new_deaths_per_million                   13365
# new_deaths_smoothed_per_million           4579
# reproduction_rate                        18314
# icu_patients                             84927
# icu_patients_per_million                 84927
# hosp_patients                            82631
# hosp_patients_per_million                82631
# weekly_icu_admissions                    93580
# weekly_icu_admissions_per_million        93580
# weekly_hosp_admissions                   92945
# weekly_hosp_admissions_per_million       92945
# new_tests                                51799
# total_tests                              52106
# total_tests_per_thousand                 52106
# new_tests_per_thousand                   51799
# new_tests_smoothed                       45005
# new_tests_smoothed_per_thousand          45005
# positive_rate                            47839
# tests_per_case                           48438
# tests_units                              43406
# total_vaccinations                       80562
# people_vaccinated                        81354
# people_fully_vaccinated                  84115
# new_vaccinations                         82830
# new_vaccinations_smoothed                70503
# total_vaccinations_per_hundred           80562
# people_vaccinated_per_hundred            81354
# people_fully_vaccinated_per_hundred      84115
# new_vaccinations_smoothed_per_million    70503
# stringency_index                         14558
# population                                 622
# population_density                        6637
# median_age                                9807
# aged_65_older                            10761
# aged_70_older                            10276
# gdp_per_capita                            9523
# extreme_poverty                          37042
# cardiovasc_death_rate                     9417
# diabetes_prevalence                       7362
# female_smokers                           27888
# male_smokers                             28863
# handwashing_facilities                   51728
# hospital_beds_per_thousand               16932
# life_expectancy                           4761
# human_development_index                   9251
# dtype: int64

# %%
len(covid_19_PMV)
# Out:
# 94441

# %%
covid_19_PMV_mean= covid_19_PMV_num_missing/len(covid_19_PMV)
covid_19_PMV_mean
# Out:
# iso_code                                 0.000000
# continent                                0.047246
# location                                 0.000000
# date                                     0.000000
# total_cases                              0.032645
# new_cases                                0.032676
# new_cases_smoothed                       0.043371
# total_deaths                             0.138139
# new_deaths                               0.136487
# new_deaths_smoothed                      0.043371
# total_cases_per_million                  0.037812
# new_cases_per_million                    0.037844
# new_cases_smoothed_per_million           0.048485
# total_deaths_per_million                 0.143169
# new_deaths_per_million                   0.141517
# new_deaths_smoothed_per_million          0.048485
# reproduction_rate                        0.193920
# icu_patients                             0.899260
# icu_patients_per_million                 0.899260
# hosp_patients                            0.874948
# hosp_patients_per_million                0.874948
# weekly_icu_admissions                    0.990883
# weekly_icu_admissions_per_million        0.990883
# weekly_hosp_admissions                   0.984159
# weekly_hosp_admissions_per_million       0.984159
# new_tests                                0.548480
# total_tests                              0.551731
# total_tests_per_thousand                 0.551731
# new_tests_per_thousand                   0.548480
# new_tests_smoothed                       0.476541
# new_tests_smoothed_per_thousand          0.476541
# positive_rate                            0.506549
# tests_per_case                           0.512892
# tests_units                              0.459610
# total_vaccinations                       0.853041
# people_vaccinated                        0.861427
# people_fully_vaccinated                  0.890662
# new_vaccinations                         0.877056
# new_vaccinations_smoothed                0.746530
# total_vaccinations_per_hundred           0.853041
# people_vaccinated_per_hundred            0.861427
# people_fully_vaccinated_per_hundred      0.890662
# new_vaccinations_smoothed_per_million    0.746530
# stringency_index                         0.154149
# population                               0.006586
# population_density                       0.070277
# median_age                               0.103843
# aged_65_older                            0.113944
# aged_70_older                            0.108809
# gdp_per_capita                           0.100835
# extreme_poverty                          0.392224
# cardiovasc_death_rate                    0.099713
# diabetes_prevalence                      0.077953
# female_smokers                           0.295295
# male_smokers                             0.305619
# handwashing_facilities                   0.547728
# hospital_beds_per_thousand               0.179287
# life_expectancy                          0.050412
# human_development_index                  0.097955
# dtype: float64

# %%
covid_19_PMV.isna().mean().round(4) * 100
# Out:
# iso_code                                  0.00
# continent                                 4.72
# location                                  0.00
# date                                      0.00
# total_cases                               3.26
# new_cases                                 3.27
# new_cases_smoothed                        4.34
# total_deaths                             13.81
# new_deaths                               13.65
# new_deaths_smoothed                       4.34
# total_cases_per_million                   3.78
# new_cases_per_million                     3.78
# new_cases_smoothed_per_million            4.85
# total_deaths_per_million                 14.32
# new_deaths_per_million                   14.15
# new_deaths_smoothed_per_million           4.85
# reproduction_rate                        19.39
# icu_patients                             89.93
# icu_patients_per_million                 89.93
# hosp_patients                            87.49
# hosp_patients_per_million                87.49
# weekly_icu_admissions                    99.09
# weekly_icu_admissions_per_million        99.09
# weekly_hosp_admissions                   98.42
# weekly_hosp_admissions_per_million       98.42
# new_tests                                54.85
# total_tests                              55.17
# total_tests_per_thousand                 55.17
# new_tests_per_thousand                   54.85
# new_tests_smoothed                       47.65
# new_tests_smoothed_per_thousand          47.65
# positive_rate                            50.65
# tests_per_case                           51.29
# tests_units                              45.96
# total_vaccinations                       85.30
# people_vaccinated                        86.14
# people_fully_vaccinated                  89.07
# new_vaccinations                         87.71
# new_vaccinations_smoothed                74.65
# total_vaccinations_per_hundred           85.30
# people_vaccinated_per_hundred            86.14
# people_fully_vaccinated_per_hundred      89.07
# new_vaccinations_smoothed_per_million    74.65
# stringency_index                         15.41
# population                                0.66
# population_density                        7.03
# median_age                               10.38
# aged_65_older                            11.39
# aged_70_older                            10.88
# gdp_per_capita                           10.08
# extreme_poverty                          39.22
# cardiovasc_death_rate                     9.97
# diabetes_prevalence                       7.80
# female_smokers                           29.53
# male_smokers                             30.56
# handwashing_facilities                   54.77
# hospital_beds_per_thousand               17.93
# life_expectancy                           5.04
# human_development_index                   9.80
# dtype: float64

# %%
covid_19_filtered= covid_19_PMV[['location','date','people_vaccinated','people_fully_vaccinated','population','population_density','gdp_per_capita']]
covid_19_filtered
# Out:
#           location        date  people_vaccinated  people_fully_vaccinated  \
# 0      Afghanistan  2020-02-24                NaN                      NaN
# 1      Afghanistan  2020-02-25                NaN                      NaN
# 2      Afghanistan  2020-02-26                NaN                      NaN
# 3      Afghanistan  2020-02-27                NaN                      NaN
# 4      Afghanistan  2020-02-28                NaN                      NaN
# ...            ...         ...                ...                      ...
# 94436     Zimbabwe  2021-06-04           685564.0                 370674.0
# 94437     Zimbabwe  2021-06-05           686636.0                 375315.0
# 94438     Zimbabwe  2021-06-06           687321.0                 380786.0
# 94439     Zimbabwe  2021-06-07           688696.0                 385275.0
# 94440     Zimbabwe  2021-06-08                NaN                      NaN
#
#        population  population_density  gdp_per_capita
# 0      38928341.0              54.422        1803.987
# 1      38928341.0              54.422        1803.987
# 2      38928341.0              54.422        1803.987
# 3      38928341.0              54.422        1803.987
# 4      38928341.0              54.422        1803.987
# ...           ...                 ...             ...
# 94436  14862927.0              42.729        1899.775
# 94437  14862927.0              42.729        1899.775
# 94438  14862927.0              42.729        1899.775
# 94439  14862927.0              42.729        1899.775
# 94440  14862927.0              42.729        1899.775
#
# [94441 rows x 7 columns]

# %%
covid_19_filtered.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
covid_19_counts= covid_19_filtered["location"].value_counts()
covid_19_counts
# Out:
# World           164
# Germany         163
# Belgium         160
# Israel          155
# Denmark         155
#                ...
# Gambia            1
# Tajikistan        1
# Lesotho           1
# Turkmenistan      1
# Ghana             1
# Name: location, Length: 161, dtype: int64

# %%
covid_19_counts[covid_19_counts>1].index
# Out:
# Index(['World', 'Germany', 'Belgium', 'Israel', 'Denmark', 'Canada',
#        'Slovenia', 'United Kingdom', 'Estonia', 'Chile',
#        ...
#        'Mozambique', 'Togo', 'Bahamas', 'Benin', 'Kyrgyzstan',
#        'Central African Republic', 'Timor', 'Malawi', 'Fiji', 'Congo'],
#       dtype='object', length=153)

# %%
covid_19_filtered2=covid_19_filtered["location"].isin(covid_19_counts[covid_19_counts>1].index)
covid_19_filtered2
# Out:
# 442      True
# 451      True
# 455      True
# 457      True
# 458      True
#          ...
# 94435    True
# 94436    True
# 94437    True
# 94438    True
# 94439    True
# Name: location, Length: 8702, dtype: bool

# %%
covid_19_filter= covid_19_filtered[covid_19_filtered2]
covid_19_filter
# Out:
#           location        date  people_vaccinated  people_fully_vaccinated  \
# 442    Afghanistan  2021-05-11           448878.0                  55624.0
# 451    Afghanistan  2021-05-20           470341.0                  77560.0
# 455    Afghanistan  2021-05-24           476367.0                  96910.0
# 457    Afghanistan  2021-05-26           479372.0                 111082.0
# 458    Afghanistan  2021-05-27           479574.0                 113739.0
# ...            ...         ...                ...                      ...
# 94435     Zimbabwe  2021-06-03           684164.0                 364340.0
# 94436     Zimbabwe  2021-06-04           685564.0                 370674.0
# 94437     Zimbabwe  2021-06-05           686636.0                 375315.0
# 94438     Zimbabwe  2021-06-06           687321.0                 380786.0
# 94439     Zimbabwe  2021-06-07           688696.0                 385275.0
#
#        population  population_density  gdp_per_capita
# 442    38928341.0              54.422        1803.987
# 451    38928341.0              54.422        1803.987
# 455    38928341.0              54.422        1803.987
# 457    38928341.0              54.422        1803.987
# 458    38928341.0              54.422        1803.987
# ...           ...                 ...             ...
# 94435  14862927.0              42.729        1899.775
# 94436  14862927.0              42.729        1899.775
# 94437  14862927.0              42.729        1899.775
# 94438  14862927.0              42.729        1899.775
# 94439  14862927.0              42.729        1899.775
#
# [8694 rows x 7 columns]

# %%
covid_19_filter['location'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Angola', 'Antigua and Barbuda',
#        'Argentina', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bolivia',
#        'Bosnia and Herzegovina', 'Brazil', 'Brunei', 'Bulgaria',
#        'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chile', 'Colombia', 'Comoros',
#        'Congo', 'Costa Rica', 'Croatia', 'Cyprus', 'Czechia', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Estonia', 'Fiji', 'Finland',
#        'France', 'Gabon', 'Georgia', 'Germany', 'Greece', 'Grenada',
#        'Guatemala', 'Guinea', 'Guyana', 'Honduras', 'Hong Kong',
#        'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Ireland',
#        'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan',
#        'Kenya', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon',
#        'Lithuania', 'Luxembourg', 'Macao', 'Malawi', 'Malaysia',
#        'Maldives', 'Mali', 'Malta', 'Mauritania', 'Mauritius', 'Mexico',
#        'Moldova', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique',
#        'Myanmar', 'Namibia', 'Nepal', 'Netherlands', 'New Zealand',
#        'Niger', 'Nigeria', 'North Macedonia', 'Norway', 'Oman',
#        'Pakistan', 'Palestine', 'Panama', 'Paraguay', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia',
#        'Saint Kitts and Nevis', 'Saint Lucia', 'San Marino',
#        'Sao Tome and Principe', 'Senegal', 'Serbia', 'Seychelles',
#        'Sierra Leone', 'Singapore', 'Sint Maarten (Dutch part)',
#        'Slovakia', 'Slovenia', 'Solomon Islands', 'South Africa',
#        'South Korea', 'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'Sweden',
#        'Switzerland', 'Thailand', 'Timor', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Uzbekistan', 'Vietnam', 'World', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
covid_19_final=covid_19_filter[covid_19_filter.location != 'World']
covid_19_final
# Out:
#           location        date  people_vaccinated  people_fully_vaccinated  \
# 442    Afghanistan  2021-05-11           448878.0                  55624.0
# 451    Afghanistan  2021-05-20           470341.0                  77560.0
# 455    Afghanistan  2021-05-24           476367.0                  96910.0
# 457    Afghanistan  2021-05-26           479372.0                 111082.0
# 458    Afghanistan  2021-05-27           479574.0                 113739.0
# ...            ...         ...                ...                      ...
# 94435     Zimbabwe  2021-06-03           684164.0                 364340.0
# 94436     Zimbabwe  2021-06-04           685564.0                 370674.0
# 94437     Zimbabwe  2021-06-05           686636.0                 375315.0
# 94438     Zimbabwe  2021-06-06           687321.0                 380786.0
# 94439     Zimbabwe  2021-06-07           688696.0                 385275.0
#
#        population  population_density  gdp_per_capita
# 442    38928341.0              54.422        1803.987
# 451    38928341.0              54.422        1803.987
# 455    38928341.0              54.422        1803.987
# 457    38928341.0              54.422        1803.987
# 458    38928341.0              54.422        1803.987
# ...           ...                 ...             ...
# 94435  14862927.0              42.729        1899.775
# 94436  14862927.0              42.729        1899.775
# 94437  14862927.0              42.729        1899.775
# 94438  14862927.0              42.729        1899.775
# 94439  14862927.0              42.729        1899.775
#
# [8530 rows x 7 columns]

# %%
covid_19_final['location'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Angola', 'Antigua and Barbuda',
#        'Argentina', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bolivia',
#        'Bosnia and Herzegovina', 'Brazil', 'Brunei', 'Bulgaria',
#        'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chile', 'Colombia', 'Comoros',
#        'Congo', 'Costa Rica', 'Croatia', 'Cyprus', 'Czechia', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Estonia', 'Fiji', 'Finland',
#        'France', 'Gabon', 'Georgia', 'Germany', 'Greece', 'Grenada',
#        'Guatemala', 'Guinea', 'Guyana', 'Honduras', 'Hong Kong',
#        'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Ireland',
#        'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan',
#        'Kenya', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon',
#        'Lithuania', 'Luxembourg', 'Macao', 'Malawi', 'Malaysia',
#        'Maldives', 'Mali', 'Malta', 'Mauritania', 'Mauritius', 'Mexico',
#        'Moldova', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique',
#        'Myanmar', 'Namibia', 'Nepal', 'Netherlands', 'New Zealand',
#        'Niger', 'Nigeria', 'North Macedonia', 'Norway', 'Oman',
#        'Pakistan', 'Palestine', 'Panama', 'Paraguay', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia',
#        'Saint Kitts and Nevis', 'Saint Lucia', 'San Marino',
#        'Sao Tome and Principe', 'Senegal', 'Serbia', 'Seychelles',
#        'Sierra Leone', 'Singapore', 'Sint Maarten (Dutch part)',
#        'Slovakia', 'Slovenia', 'Solomon Islands', 'South Africa',
#        'South Korea', 'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'Sweden',
#        'Switzerland', 'Thailand', 'Timor', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Uzbekistan', 'Vietnam', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
covid_19_final.to_csv('covid_19_ready_PMV.csv')

# %%
covid_19_ready_PMV = pd.read_csv('covid_19_ready_PMV.csv')
covid_19_ready_PMV.head()
# Out:
#    Unnamed: 0     location        date  people_vaccinated  \
# 0         442  Afghanistan  2021-05-11           448878.0
# 1         451  Afghanistan  2021-05-20           470341.0
# 2         455  Afghanistan  2021-05-24           476367.0
# 3         457  Afghanistan  2021-05-26           479372.0
# 4         458  Afghanistan  2021-05-27           479574.0
#
#    people_fully_vaccinated  population  population_density  gdp_per_capita
# 0                  55624.0  38928341.0              54.422        1803.987
# 1                  77560.0  38928341.0              54.422        1803.987
# 2                  96910.0  38928341.0              54.422        1803.987
# 3                 111082.0  38928341.0              54.422        1803.987
# 4                 113739.0  38928341.0              54.422        1803.987

# %%
covid_19_filtered_PMV= covid_19_ready_PMV[['date','people_fully_vaccinated']]
covid_19_filtered_PMV
# Out:
#             date  people_fully_vaccinated
# 0     2021-05-11                  55624.0
# 1     2021-05-20                  77560.0
# 2     2021-05-24                  96910.0
# 3     2021-05-26                 111082.0
# 4     2021-05-27                 113739.0
# ...          ...                      ...
# 8525  2021-06-03                 364340.0
# 8526  2021-06-04                 370674.0
# 8527  2021-06-05                 375315.0
# 8528  2021-06-06                 380786.0
# 8529  2021-06-07                 385275.0
#
# [8530 rows x 2 columns]

# %%
covid_19_filtered_PMV.to_csv('covid_19_filtered_PMV.csv')

# %% [markdown]
# ### Step1-Read the data

# %%
df= pd.read_csv('covid_19_filtered_PMV.csv', parse_dates=['date'], index_col=['date'])
df
# Out:
#             Unnamed: 0  people_fully_vaccinated
# date
# 2021-05-11           0                  55624.0
# 2021-05-20           1                  77560.0
# 2021-05-24           2                  96910.0
# 2021-05-26           3                 111082.0
# 2021-05-27           4                 113739.0
# ...                ...                      ...
# 2021-06-03        8525                 364340.0
# 2021-06-04        8526                 370674.0
# 2021-06-05        8527                 375315.0
# 2021-06-06        8528                 380786.0
# 2021-06-07        8529                 385275.0
#
# [8530 rows x 2 columns]

# %% [markdown]
# ### Resample the data : Agregation of data, Daily to monthly

# %%
tsdf= df['people_fully_vaccinated'].resample('D').sum()
tsdf.head(20)
# Out:
# date
# 2020-12-27         17.0
# 2020-12-28         55.0
# 2020-12-29        788.0
# 2020-12-30        920.0
# 2020-12-31       1069.0
# 2021-01-01       1076.0
# 2021-01-02       1372.0
# 2021-01-03      23348.0
# 2021-01-04       1432.0
# 2021-01-05       1477.0
# 2021-01-06       1936.0
# 2021-01-07       2613.0
# 2021-01-08       3905.0
# 2021-01-09       4898.0
# 2021-01-10     652295.0
# 2021-01-11     442348.0
# 2021-01-12     494209.0
# 2021-01-13     570918.0
# 2021-01-14    1994563.0
# 2021-01-15    2311859.0
# Freq: D, Name: people_fully_vaccinated, dtype: float64

# %%
tsdf.plot()

# %% [markdown]
# ### Stationarity check

# %%
import statsmodels.api as sm

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adftest= adfuller(tsdf)

# %%
print ('pvalue of adfuller test is :', adftest[1])
# Out:
# pvalue of adfuller test is : 0.3068853066434939

# %% [markdown]
# ### Pavlaue > .05 = time series is not stationary

# %% [markdown]
# ### Step 4 Train test split

# %%
len(tsdf('days'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-4a35325058a1> in <module>()
# ----> 1 len(tsdf('days'))
#
# TypeError: 'Series' object is not callable

# %%
train=tsdf[:5]
test= tsdf[5:]

# %% [markdown]
# ### STep 5 : Build Arima model

# %%
#p =4 , d=2, q=4

# %% [markdown]
# ### Step 6 Build ARIMA model

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
model=ARIMA(train,order=(4,2,4)).fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-69c03bc1a77b> in <module>()
# ----> 1 model=ARIMA(train,order=(4,2,4)).fit()
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#     986         else:
#     987             mod = super(ARIMA, cls).__new__(cls)
# --> 988             mod.__init__(endog, order, exog, dates, freq, missing)
#     989             return mod
#     990
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#    1005             # in the predict method
#    1006             raise ValueError("d > 2 is not supported")
# -> 1007         super(ARIMA, self).__init__(endog, (p, q), exog, dates, freq, missing)
#    1008         self.k_diff = d
#    1009         self._first_unintegrate = unintegrate_levels(self.endog[:d], d)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#     426             raise ValueError('endog must be 1-d or 2-d with 1 column')
#     427         exog = self.data.exog  # get it after it's gone through processing
# --> 428         _check_estimable(len(self.endog), sum(order))
#     429         self.k_ar = k_ar = order[0]
#     430         self.k_ma = k_ma = order[1]
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py in _check_estimable(nobs, n_params)
#     408 def _check_estimable(nobs, n_params):
#     409     if nobs <= n_params:
# --> 410         raise ValueError("Insufficient degrees of freedom to estimate")
#     411
#     412
#
# ValueError: Insufficient degrees of freedom to estimate

# %%
pred=model.predict(start= en(train),end=len(tsdf)-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-ababd9404901> in <module>()
# ----> 1 pred=model.predict(start= en(train),end=len(tsdf)-1)
#
# NameError: name 'model' is not defined

# %%
from sklearn.metrics import mean_squared_error
error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-98f2c9076781> in <module>()
#       1 from sklearn.metrics import mean_squared_error
# ----> 2 error
#
# NameError: name 'error' is not defined

# %%
error =np.sqrt(mean_squared_error(test,pred))
